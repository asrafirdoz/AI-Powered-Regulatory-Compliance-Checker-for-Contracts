# %% [markdown]
# <a href="https://colab.research.google.com/github/asrafirdoz/AI-Powered-Regulatory-Compliance-Checker-for-Contracts/blob/main/Sql.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 🛒 E-Commerce Database — Brief Overview
# An E-Commerce Database stores and manages data for an online shopping system like Amazon or Flipkart.
#
# It handles:
#
# Customers 👤
#
# Products 📦
#
# Orders 🧾
#
# Payments 💳
#
# Inventory📊
#
# 📌 Main Tables Structure
#
# 1️⃣ Customers Table
#
# Stores customer details.
#
# Copy code
#
# customer_id (PK)
#
# name
#
# email
#
# city
#
# phone
#
# Products Table
#
# Stores product information.
#
# Copy code
#
# product_id (PK)
#
# product_name
#
# category
#
# price
#
# stock
# 3️⃣ Orders Table
#
# Stores order summary.
#
# Copy code
#
#
# order_id (PK)
#
# customer_id (FK)
#
# order_date
#
# total_amount
#
# 4️⃣ Order_Items Table
#
# Stores product details inside each order.
#
# Copy code
#
# order_id (FK)
#
# product_id (FK)
#
# quantity
#
# price
#
# 👉 This table handles many-to-many relationship between Orders and Products.
#
# 🔗 Relationships
#
# One customer → Many orders
#
# One order → Many products
#
# One product → Many order items
#
# 🎯 Why It’s Important?
#
# Used for:
#
# Tracking sales
#
# Managing inventory
#
# Generating reports
#
# Customer analytics
#
# Recommendation systems
#
# 🔥 Common SQL Tasks in E-Commerce
#
# Find top-selling product
#
# Calculate monthly sales
#
# Find customers who spent more than ₹50,000
#
# Update stock after purchase
#
# Find most active customers
#
# 🛒 E-Commerce Database — Interview Questions:
#
# 1️⃣ Find Total Orders Placed by Each Customer?
#
# 2️⃣ Find Top 5 Most Sold Products?
#
# 3️⃣ Find Customers Who Never Placed an Order?
#
# 4️⃣ Find Total Revenue Generated?
#
# 5️⃣ Find Monthly Sales Report?
#
# 6️⃣ Find Customers Who Spent More Than ₹50,000?
#
# 7️⃣ Find Top 3 Products in Each Category?
#
# 8️⃣ Find Running Total of Sales?
#
# 9️⃣ Find Repeat Customers (Ordered More Than Once)?
#
# 🔟 Find Product With Highest Revenue?
#
# 💼 Design-Based Interview Questions:
#
# Design database schema for an E-Commerce platform?
#
# How to handle stock updates after order?
#
# How to improve slow product search query?
#
# What indexes will you create?
#
# How to prevent duplicate orders?
#
# Explain normalization in this database?
